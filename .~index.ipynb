# %% [markdown]
# ## Bringing It All Together: Data Analysis and Visualization in Python

# %% [markdown]
# ## Introduction
#
# Okay, we've covered a lot in this section. We have learned how to work with lists, dictionaries, functions, and even visualizing data with libraries like folium and plotly. In this lab, we will bring all these skills together and flex our new found data science skills. As burgeoning data scienctists in the tech community, we are going to need to find ways to grow our network and find ways to learn more skills. Meetup is a great site for finding groups catered to particular interests and industries. This is a great way for us to expand our network and find events to learn more about how python and data science is being used in the marketplace.
#
# Our goal is to visualize data from the Meetup API to show which cities have the most active Python and Data Science communities. Let's get started!

# %% [markdown]
# ## Objectives
#
# * Understand how to programmatically format outside data
# * Choose proper datatypes and formats for comparing data and creating visualizations
# * Use higher level iterators like 'map' and 'filter'
# * Write re-usable functions to make [DRY code](https://stackoverflow.com/questions/6453235/what-does-damp-not-dry-mean-when-talking-about-unit-tests)

# %% [markdown]
# ## Formatting Our Data

# %% [markdown]
# Okay, so first things first, we have to figure out where our data is coming from. Typically, we would query an API, which acts like a database for a website. APIs can contain information for any number of things. In the example of meetup, the API has all the information on every group, event, all member profiles, the interests for those members, etc. Once we successfully query the information we want, we can format it and use it for our own purposes. To make it easier, we've already queried the meetup API for our data and saved it in this repository. We can now simply import the data and begin to work with it.

# %% [markdown]
# We have gathered information for Python focused meetup groups in a 15 mile radius of New York, San Francisco, Denver, Austin, and Atlanta.
#
# Let's take a look at what one of our groups looks like:

# %%
from groups import data

# %%
data[0]
# Out:
# {'utc_offset': -14400000,
#  'country': 'US',
#  'visibility': 'public',
#  'city': 'New York',
#  'timezone': 'US/Eastern',
#  'created': 1150197645000,
#  'topics': [{'urlkey': 'opensource', 'name': 'Open Source', 'id': 563},
#   {'urlkey': 'python', 'name': 'Python', 'id': 1064},
#   {'urlkey': 'softwaredev', 'name': 'Software Development', 'id': 3833},
#   {'urlkey': 'django', 'name': 'Django', 'id': 10553},
#   {'urlkey': 'web-development', 'name': 'Web Development', 'id': 15582},
#   {'urlkey': 'computer-programming',
#    'name': 'Computer programming',
#    'id': 48471},
#   {'urlkey': 'python-web-development',
#    'name': 'Python Web Development',
#    'id': 917242}],
#  'link': 'https://www.meetup.com/nycpython/',
#  'rating': 4.64,
#  'description': '<p>Meet other local Python Programming Language enthusiasts!</p>',
#  'lon': -73.98999786376953,
#  'group_photo': {'highres_link': 'https://secure.meetupstatic.com/photos/event/c/a/1/4/highres_313251732.jpeg',
#   'photo_id': 313251732,
#   'base_url': 'https://secure.meetupstatic.com',
#   'type': 'event',
#   'photo_link': 'https://secure.meetupstatic.com/photos/event/c/a/1/4/600_313251732.jpeg',
#   'thumb_link': 'https://secure.meetupstatic.com/photos/event/c/a/1/4/thumb_313251732.jpeg'},
#  'join_mode': 'open',
#  'organizer': {'member_id': 64072142,
#   'name': 'James Powell',
#   'photo': {'highres_link': 'https://secure.meetupstatic.com/photos/member/d/6/1/c/highres_157134812.jpeg',
#    'photo_id': 157134812,
#    'base_url': 'https://secure.meetupstatic.com',
#    'type': 'member',
#    'photo_link': 'https://secure.meetupstatic.com/photos/member/d/6/1/c/member_157134812.jpeg',
#    'thumb_link': 'https://secure.meetupstatic.com/photos/member/d/6/1/c/thumb_157134812.jpeg'}},
#  'members': 11987,
#  'name': 'The New York Python Meetup Group',
#  'id': 263790,
#  'state': 'NY',
#  'urlname': 'nycpython',
#  'category': {'name': 'tech', 'id': 34, 'shortname': 'tech'},
#  'lat': 40.75,
#  'who': 'Python Programmers and Users'}

# %% [markdown]
# Wow, that is a lot of information! We can see that the first element of the `data` list is a dictionary representing one of the groups we've pulled from the Meetup API. Each group will take this same form, that is they will have the same keys (i.e. description, state, city, lat, lon, category, topics, etc.) We can more easily see a list of keys by using the keys() method we've used in earlier labs.

# %%
data[0].keys()
# Out:
# dict_keys(['utc_offset', 'country', 'visibility', 'city', 'timezone', 'created', 'topics', 'link', 'rating', 'description', 'lon', 'group_photo', 'join_mode', 'organizer', 'members', 'name', 'id', 'state', 'urlname', 'category', 'lat', 'who'])

# %% [markdown]
# Great! we have an idea of what we're working with now. How can we use this data to answer some of our questions from above? Let's start with finding out which cities have the most python groups.
#
# We can do this by creating a dictionary and giving it keys for each city in our list of groups that we have imported as the variable, `data`.
#
# Let's write a function that will do this for us and call it `create_cities_dictionary`, which should return a dictionary with keys for each city that point to lists with all the meetup groups in that city.

# %%
def create_cities_dictionary(group_data):
    city_dict = {}
    for group in group_data:
        if group["city"] in city_dict:
            city_dict[group["city"]].append(group)
        else: 
            city_dict[group["city"]] = [group]
    return city_dict

cities_dict = create_cities_dictionary(data)
cities_dict # call our create_cities_dictionary function here to assign its return value to the variable cities_dict
# Out:
# {'New York': [{'utc_offset': -14400000,
#    'country': 'US',
#    'visibility': 'public',
#    'city': 'New York',
#    'timezone': 'US/Eastern',
#    'created': 1150197645000,
#    'topics': [{'urlkey': 'opensource', 'name': 'Open Source', 'id': 563},
#     {'urlkey': 'python', 'name': 'Python', 'id': 1064},
#     {'urlkey': 'softwaredev', 'name': 'Software Development', 'id': 3833},
#     {'urlkey': 'django', 'name': 'Django', 'id': 10553},
#     {'urlkey': 'web-development', 'name': 'Web Development', 'id': 15582},
#     {'urlkey': 'computer-programming',
#      'name': 'Computer programming',
#      'id': 48471},
#     {'urlkey': 'python-web-development',
#      'name': 'Python Web Development',
#      'id': 917242}],
#    'link': 'https://www.meetup.com/nycpython/',
#    'rating': 4.64,
#    'description': '<p>Meet other local Python Programming Language enthusiasts!</p>',
#    'lon': -73.98999786376953,
#    'group_photo': {'highres_link': 'https://secure.meetupstatic.com/photos/event/c/a/1/4/highres_313251732.jpeg',
#     'photo_id': 313251732,
#     'base_url': 'https://secure.meetupstatic.com',
#     'type': 'event',
#     'photo_link': 'https://secure.meetupstatic.com/photos/event/c/a/1/4/600_313251732.jpeg',
#     'thumb_link': 'https://secure.meetupstatic.com/photos/event/c/a/1/4/thumb_313251732.jpeg'},
#    'join_mode': 'open',
#    'organizer': {'member_id': 64072142,
#     'name': 'James Powell',
#     'photo': {'highres_link': 'https://secure.meetupstatic.com/photos/member/d/6/1/c/highres_157134812.jpeg',
#      'photo_id': 157134812,
#      'base_url': 'https://secure.meetupstatic.com',
#      'type': 'member',
#      'photo_link': 'https://secure.meetupstatic.com/photos/member/d/6/1/c/member_157134812.jpeg',
#      'thumb_link': 'https://secure.meetupstatic.com/photos/member/d/6/1/c/thumb_157134812.jpeg'}},
#    'members': 11987,
#    'name': 'The New York Python Meetup Group',
#    'id': 263790,
#    'state': 'NY',
#    'urlname': 'nycpython',
#    'category': {'name': 'tech', 'id': 34, 'shortname': 'tech'},
#    'lat': 40.75,
#    'who': 'Python Programmers and Users'},
#   {'utc_offset': -14400000,
#    'country': 'US',
#    'visibility': 'public',
#    'city': 'New York',
#    'timezone': 'US/Eastern',
#    'created': 1184597278000,
#    'topics': [{'urlkey': 'java', 'name': 'Java', 'id': 189},
#     {'urlkey': 'python', 'name': 'Python', 'id': 1064},
#     {'urlkey': 'softwaredev', 'name': 'Software Development', 'id': 3833},
#     {'urlkey': 'javascript', 'name': 'JavaScript', 'id': 7029},
#     {'urlkey': 'web-development', 'name': 'Web Development', 'id': 15582},
#     {'urlkey': 'software-engineering',
#      'name': 'Software Engineering',
#      'id': 16325},
#     {'urlkey': 'big-data', 'name': 'Big Data', 'id': 18062},
#     {'urlkey': 'user-experience', 'name': 'User Experience', 'id': 19243},
#     {'urlkey': 'hacking', 'name': 'Hacking', 'id': 21123},
#     {'urlkey': 'mobile-development',
#      'name': 'Mobile Development',
#      'id': 21441},
#     {'urlkey': 'startup-businesses',
#      'name': 'Startup Businesses',
#      'id': 21681},
#     {'urlkey': 'job-search', 'name': 'Job Search', 'id': 21900},
#     {'urlkey': 'computer-programming',
#      'name': 'Computer programming',
#      'id': 48471},
#     {'urlkey': 'devops', 'name': 'DevOps', 'id': 87614},
#     {'urlkey': 'front-end-development',
#      'name': 'Front-end Development',
#      'id': 100479}],
#    'link': 'https://www.meetup.com/nytechtalent/',
#    'rating': 4,
#    'description': '<p>Are you a techie, programmer, designer, data scientist, or marketing expert? Join our group for tech jobs and information about discussion meetups near you. <br></p>\n<p> <br></p>',
#    'lon': -73.98999786376953,
#    'group_photo': {'highres_link': 'https://secure.meetupstatic.com/photos/event/b/3/9/8/highres_454065976.jpeg',
#     'photo_id': 454065976,
#     'base_url': 'https://secure.meetupstatic.com',
#     'type': 'event',
#     'photo_link': 'https://secure.meetupstatic.com/photos/event/b/3/9/8/600_454065976.jpeg',
#     'thumb_link': 'https://secure.meetupstatic.com/photos/event/b/3/9/8/thumb_454065976.jpeg'},
#    'join_mode': 'open',
#    'organizer': {'member_id': 3361856,
#     'name': 'Lucienne Canet',
#     'photo': {'highres_link': 'https://secure.meetupstatic.com/photos/member/b/a/1/2/highres_253787634.jpeg',
#      'photo_id': 253787634,
#      'base_url': 'https://secure.meetupstatic.com',
#      'type': 'member',
#      'photo_link': 'https://secure.meetupstatic.com/photos/member/b/a/1/2/member_253787634.jpeg',
#      'thumb_link': 'https://secure.meetupstatic.com/photos/member/b/a/1/2/thumb_253787634.jpeg'}},
#    'members': 998,
#    'name': 'NY Tech Talent',
#    'id': 571602,
#    'state': 'NY',
#    'urlname': 'nytechtalent',
#    'category': {'name': 'career/business',
#     'id': 2,
#     'shortname': 'career-business'},
#    'lat': 40.75,
#    'who': 'jobseekers'},
#   {'utc_offset': -14400000,
#    'country': 'US',
#    'visibility': 'public',
#    'city': 'New York',
#    'timezone': 'US/Eastern',
#    'created': 1222189300000,
#    'topics': [{'urlkey': 'opensource', 'name': 'Open Source', 'id': 563},
#     {'urlkey': 'mysql', 'name': 'MySQL', 'id': 789},
#     {'urlkey': 'python', 'name': 'Python', 'id': 1064},
#     {'urlkey': 'databasepro', 'name': 'Database Professionals', 'id': 1245},
#     {'urlkey': 'oracle', 'name': 'Oracle', 'id': 2544},
#     {'urlkey': 'javascript', 'name': 'JavaScript', 'id': 7029},
#     {'urlkey': 'sqlserver', 'name': 'SQL Server', 'id': 7463},
#     {'urlkey': 'postgresql', 'name': 'PostgreSQL', 'id': 10361},
#     {'urlkey': 'web-development', 'name': 'Web Development', 'id': 15582},
#     {'urlkey': 'hadoop', 'name': 'Hadoop', 'id': 18060},
#     {'urlkey': 'big-data', 'name': 'Big Data', 'id': 18062},
#     {'urlkey': 'database-development',
#      'name': 'Database Development',
#      'id': 21506},
#     {'urlkey': 'geospatial', 'name': 'Geospatial', 'id': 27142},
#     {'urlkey': 'nosql', 'name': 'NoSQL', 'id': 58162},
#     {'urlkey': 'postgres', 'name': 'Postgres', 'id': 208041}],
#    'link': 'https://www.meetup.com/postgres-nyc/',
#    'rating': 4.54,
#    'description': "<p>Meet others in your local area interested in PostgreSQL: The World's Most Advanced Open Source Database. Discuss this open source database and share the tips and tricks you've learned using it.</p>",
#    'lon': -73.98999786376953,
#    'group_photo': {'highres_link': 'https://secure.meetupstatic.com/photos/event/b/d/f/5/highres_17148629.jpeg',
#     'photo_id': 17148629,
#     'base_url': 'https://secure.meetupstatic.com',
#     'type': 'event',
#     'photo_link': 'https://secure.meetupstatic.com/photos/event/b/d/f/5/600_17148629.jpeg',
#     'thumb_link': 'https://secure.meetupstatic.com/photos/event/b/d/f/5/thumb_17148629.jpeg'},
#    'join_mode': 'open',
#    'organizer': {'member_id': 8206413,
#     'name': 'Mason Sharp',
#     'photo': {'highres_link': 'https://secure.meetupstatic.com/photos/member/d/9/b/5/highres_5395733.jpeg',
#      'photo_id': 5395733,
#      'base_url': 'https://secure.meetupstatic.com',
#      'type': 'member',
#      'photo_link': 'https://secure.meetupstatic.com/photos/member/d/9/b/5/member_5395733.jpeg',
#      'thumb_link': 'https://secure.meetupstatic.com/photos/member/d/9/b/5/thumb_5395733.jpeg'}},
#    'members': 2542,
#    'name': 'New York City PostgreSQL User Group',
#    'id': 1288046,
#    'state': 'NY',
#    'urlname': 'postgres-nyc',
#    'category': {'name': 'tech', 'id': 34, 'shortname': 'tech'},
#    'lat': 40.7599983215332,
#    'who': 'Database Users'},
#   {'utc_offset': -14400000,
#    'country': 'US',
#    'visibility': 'public',
#    'city': 'New York',
#    'timezone': 'US/Eastern',
#    'created': 1255352896000,
#    'topics': [{'urlkey': 'opensource', 'name': 'Open Source', 'id': 563},
#     {'urlkey': 'python', 'name': 'Python', 'id': 1064},
#     {'urlkey': 'web', 'name': 'Web Technology', 'id': 10209},
#     {'urlkey': 'django', 'name': 'Django', 'id': 10553},
#     {'urlkey': 'technology', 'name': 'Technology', 'id': 10579},
#     {'urlkey': 'web-development', 'name': 'Web Development', 'id': 15582},
#     {'urlkey': 'computer-programming',
#      'name': 'Computer programming',
#      'id': 48471}],
#    'link': 'https://www.meetup.com/django-nyc/',
#    'rating': 4.64,
#    'description': '<p>Django-nyc\'s goal is to create a community for those interested in Django to meet, share ideas, create, learn, and have a good time. The focus will be Django and web application design and development. Python will obviously be an underlining theme, but there are specific python groups focused on python solely and that\'s not us. We want to give Django the attention it deserves.</p>\n<p>Please be sure to also review out <a href="http://www.djangonyc.org/pages/Code_of_Conduct/">Code of Conduct</a> and <a href="http://www.djangonyc.org/pages/Diversity_Statement/">Diversity Statement</a>.</p>\n<p>You can also find us on <a href="http://twitter.com/django_nyc/">Twitter</a> and <a href="https://plus.google.com/100843105779649249572">Google+</a>.</p>',
#    'lon': -73.98999786376953,
#    'group_photo': {'highres_link': 'https://secure.meetupstatic.com/photos/event/3/3/c/5/highres_11773253.jpeg',
#     'photo_id': 11773253,
#     'base_url': 'https://secure.meetupstatic.com',
#     'type': 'event',
#     'photo_link': 'https://secure.meetupstatic.com/photos/event/3/3/c/5/600_11773253.jpeg',
#     'thumb_link': 'https://secure.meetupstatic.com/photos/event/3/3/c/5/thumb_11773253.jpeg'},
#    'join_mode': 'open',
#    'organizer': {'member_id': 5251431,
#     'name': 'Geoffrey Sechter',
#     'photo': {'highres_link': 'https://secure.meetupstatic.com/photos/member/e/1/f/c/highres_69477852.jpeg',
#      'photo_id': 69477852,
#      'base_url': 'https://secure.meetupstatic.com',
#      'type': 'member',
#      'photo_link': 'https://secure.meetupstatic.com/photos/member/e/1/f/c/member_69477852.jpeg',
#      'thumb_link': 'https://secure.meetupstatic.com/photos/member/e/1/f/c/thumb_69477852.jpeg'}},
#    'members': 2887,
#    'name': 'Django-NYC',
#    'id': 1538865,
#    'state': 'NY',
#    'urlname': 'django-nyc',
#    'category': {'name': 'tech', 'id': 34, 'shortname': 'tech'},
#    'lat': 40.7400016784668,
#    'who': 'Djangonauts'},
#   {'utc_offset': -14400000,
#    'country': 'US',
#    'visibility': 'public',
#    'city': 'New York',
#    'timezone': 'US/Eastern',
#    'created': 1265048616000,
#    'topics': [{'urlkey': 'linux', 'name': 'Linux', 'id': 188},
#     {'urlkey': 'apache', 'name': 'Apache', 'id': 190},
#     {'urlkey': 'php', 'name': 'PHP', 'id': 455},
#     {'urlkey': 'opensource', 'name': 'Open Source', 'id': 563},
#     {'urlkey': 'webdesign', 'name': 'Web Design', 'id': 659},
#     {'urlkey': 'mysql', 'name': 'MySQL', 'id': 789},
#     {'urlkey': 'ruby', 'name': 'Ruby', 'id': 1040},
#     {'urlkey': 'python', 'name': 'Python', 'id': 1064},
#     {'urlkey': 'softwaredev', 'name': 'Software Development', 'id': 3833},
#     {'urlkey': 'lampsoftware', 'name': 'LAMP', 'id': 10164},
#     {'urlkey': 'web', 'name': 'Web Technology', 'id': 10209},
#     {'urlkey': 'drupal', 'name': 'Drupal', 'id': 10358},
#     {'urlkey': 'django', 'name': 'Django', 'id': 10553},
#     {'urlkey': 'web-development', 'name': 'Web Development', 'id': 15582},
#     {'urlkey': 'ruby-on-rails', 'name': 'Ruby On Rails', 'id': 20837}],
#    'link': 'https://www.meetup.com/codeigniter/',
#    'rating': 4.66,
#    'description': '<p>The New York Metro CodeIgniter user group. For newbies and power users! Come network, laugh and learn!</p>',
#    'lon': -73.9800033569336,
#    'group_photo': {'highres_link': 'https://secure.meetupstatic.com/photos/event/1/8/7/f/highres_12906271.jpeg',
#     'photo_id': 12906271,
#     'base_url': 'https://secure.meetupstatic.com',
#     'type': 'event',
#     'photo_link': 'https://secure.meetupstatic.com/photos/event/1/8/7/f/600_12906271.jpeg',
#     'thumb_link': 'https://secure.meetupstatic.com/photos/event/1/8/7/f/thumb_12906271.jpeg'},
#    'join_mode': 'open',
#    'organizer': {'member_id': 9787311,
#     'name': 'Aaron Sylvan',
#     'photo': {'highres_link': 'https://secure.meetupstatic.com/photos/member/9/1/4/1/highres_12517185.jpeg',
#      'photo_id': 12517185,
#      'base_url': 'https://secure.meetupstatic.com',
#      'type': 'member',
#      'photo_link': 'https://secure.meetupstatic.com/photos/member/9/1/4/1/member_12517185.jpeg',
#      'thumb_link': 'https://secure.meetupstatic.com/photos/member/9/1/4/1/thumb_12517185.jpeg'}},
#    'members': 285,
#    'name': 'CodeIgniter PHP NYC - MVC web application framework',
#    'id': 1592365,
#    'state': 'NY',
#    'urlname': 'codeigniter',
#    'category': {'name': 'tech', 'id': 34, 'shortname': 'tech'},
#    'lat': 40.75,
#    'who': 'Members'},
#   {'utc_offset': -14400000,
#    'country': 'US',
#    'visibility': 'public',
#    'city': 'New York',
#    'timezone': 'US/Eastern',
#    'created': 1268083699000,
#    'topics': [{'urlkey': 'opensource', 'name': 'Open Source', 'id': 563},
#     {'urlkey': 'ruby', 'name': 'Ruby', 'id': 1040},
#     {'urlkey': 'python', 'name': 'Python', 'id': 1064},
#     {'urlkey': 'softwaredev', 'name': 'Software Development', 'id': 3833},
#     {'urlkey': 'newtech', 'name': 'New Technology', 'id': 9696},
#     {'urlkey': 'internetpro', 'name': 'Internet Professionals', 'id': 10102},
#     {'urlkey': 'technology', 'name': 'Technology', 'id': 10579},
#     {'urlkey': 'web-development', 'name': 'Web Development', 'id': 15582},
#     {'urlkey': 'agile-project-management',
#      'name': 'Agile Project Management',
#      'id': 21549},
#     {'urlkey': 'test-driven-development',
#      'name': 'Test Driven Development',
#      'id': 25435},
#     {'urlkey': 'selenium', 'name': 'Selenium', 'id': 27921},
#     {'urlkey': 'continuous-integration',
#      'name': 'Continuous Integration',
#      'id': 27922},
#     {'urlkey': 'test-automation', 'name': 'Test Automation', 'id': 65172},
#     {'urlkey': 'quality-assurance', 'name': 'Quality Assurance', 'id': 70576},
#     {'urlkey': 'webdriver', 'name': 'Webdriver', 'id': 85524}],
#    'link': 'https://www.meetup.com/Quality-Assurance/',
#    'rating': 4.75,
#    'description': '<p>Quality Assurance is a group for those interested in Quality Assurance, Web and Software Test Automation, QA Based Development, Ruby, Python and more.</p>',
#    'lon': -73.98999786376953,
#    'group_photo': {'highres_link': 'https://secure.meetupstatic.com/photos/event/3/b/3/highres_13560947.jpeg',
#     'photo_id': 13560947,
#     'base_url': 'https://secure.meetupstatic.com',
#     'type': 'event',
#     'photo_link': 'https://secure.meetupstatic.com/photos/event/3/b/3/600_13560947.jpeg',
#     'thumb_link': 'https://secure.meetupstatic.com/photos/event/3/b/3/thumb_13560947.jpeg'},
#    'join_mode': 'open',
#    'organizer': {'member_id': 11615863,
#     'name': 'Anthony Long',
#     'photo': {'highres_link': 'https://secure.meetupstatic.com/photos/member/e/a/5/0/highres_9539984.jpeg',
#      'photo_id': 9539984,
#      'base_url': 'https://secure.meetupstatic.com',
#      'type': 'member',
#      'photo_link': 'https://secure.meetupstatic.com/photos/member/e/a/5/0/member_9539984.jpeg',
#      'thumb_link': 'https://secure.meetupstatic.com/photos/member/e/a/5/0/thumb_9539984.jpeg'}},
#    'members': 1603,
#    'name': 'Quality Assurance',
#    'id': 1611051,
#    'state': 'NY',
#    'urlname': 'Quality-Assurance',
#    'category': {'name': 'tech', 'id': 34, 'shortname': 'tech'},
#    'lat': 40.75,
#    'who': 'Members'},
#   {'utc_offset': -14400000,
#    'country': 'US',
#    'visibility': 'public',
#    'city': 'New York',
#    'timezone': 'US/Eastern',
#    'created': 1271084266000,
#    'topics': [{'urlkey': 'java', 'name': 'Java', 'id': 189},
#     {'urlkey': 'php', 'name': 'PHP', 'id': 455},
#     {'urlkey': 'opensource', 'name': 'Open Source', 'id': 563},
#     {'urlkey': 'ruby', 'name': 'Ruby', 'id': 1040},
#     {'urlkey': 'python', 'name': 'Python', 'id': 1064},
#     {'urlkey': 'softwaredev', 'name': 'Software Development', 'id': 3833},
#     {'urlkey': 'javascript', 'name': 'JavaScript', 'id': 7029},
#     {'urlkey': 'newtech', 'name': 'New Technology', 'id': 9696},
#     {'urlkey': 'cloud-computing', 'name': 'Cloud Computing', 'id': 15167},
#     {'urlkey': 'big-data', 'name': 'Big Data', 'id': 18062},
#     {'urlkey': 'data-analytics', 'name': 'Data Analytics', 'id': 30928},
#     {'urlkey': 'computer-programming',
#      'name': 'Computer programming',
#      'id': 48471},
#     {'urlkey': 'nosql', 'name': 'NoSQL', 'id': 58162},
#     {'urlkey': 'mongodb', 'name': 'MongoDB', 'id': 121802}],
#    'link': 'https://www.meetup.com/New-York-MongoDB-User-Group/',
#    'rating': 4.5,
#    'description': '<p>This group is a place for developers to learn more about the open source, JSON-based document database MongoDB. MongoDB is the leading NoSQL database and many of the key committers are based right here in New York City. So if you are facing challenges with MySQL, Postgres or Oracle and want to explore a more flexible, scalable alternative, please join us at one of our monthly sessions. We typically meet on the third Tuesday of the month, have some pizza and network, and enjoy a presentation on MongoDB.</p>\n<p>Membership in the group is governed by our <a href="https://www.mongodb.com/community-code-of-conduct">Community Code of Conduct</a>.</p>',
#    'lon': -73.98999786376953,
#    'group_photo': {'highres_link': 'https://secure.meetupstatic.com/photos/event/e/0/1/3/highres_442077363.jpeg',
#     'photo_id': 442077363,
#     'base_url': 'https://secure.meetupstatic.com',
#     'type': 'event',
#     'photo_link': 'https://secure.meetupstatic.com/photos/event/e/0/1/3/600_442077363.jpeg',
#     'thumb_link': 'https://secure.meetupstatic.com/photos/event/e/0/1/3/thumb_442077363.jpeg'},
#    'join_mode': 'open',
#    'organizer': {'member_id': 47839632,
#     'name': 'MongoDB',
#     'photo': {'highres_link': 'https://secure.meetupstatic.com/photos/member/3/a/f/d/highres_243915101.jpeg',
#      'photo_id': 243915101,
#      'base_url': 'https://secure.meetupstatic.com',
#      'type': 'member',
#      'photo_link': 'https://secure.meetupstatic.com/photos/member/3/a/f/d/member_243915101.jpeg',
#      'thumb_link': 'https://secure.meetupstatic.com/photos/member/3/a/f/d/thumb_243915101.jpeg'}},
#    'members': 6368,
#    'name': 'New York MongoDB User Group',
#    'id': 1629296,
#    'state': 'NY',
#    'urlname': 'New-York-MongoDB-User-Group',
#    'category': {'name': 'tech', 'id': 34, 'shortname': 'tech'},
#    'lat': 40.7599983215332,
#    'who': 'Members'},
#   {'utc_offset': -14400000,
#    'country': 'US',
#    'visibility': 'public',
#    'city': 'New York',
#    'timezone': 'US/Eastern',
#    'created': 1278699547000,
#    'topics': [{'urlkey': 'gamedev', 'name': 'Game Development', 'id': 496},
#     {'urlkey': 'opensource', 'name': 'Open Source', 'id': 563},
#     {'urlkey': 'ruby', 'name': 'Ruby', 'id': 1040},
#     {'urlkey': 'python', 'name': 'Python', 'id': 1064},
#     {'urlkey': 'lisp', 'name': 'Lisp & Scheme', 'id': 2400},
#     {'urlkey': 'softwaredev', 'name': 'Software Development', 'id': 3833},
#     {'urlkey': 'newtech', 'name': 'New Technology', 'id': 9696},
#     {'urlkey': 'web-development', 'name': 'Web Development', 'id': 15582},
#     {'urlkey': 'android-developers',
#      'name': 'Android Development',
#      'id': 20346},
#     {'urlkey': 'hacking', 'name': 'Hacking', 'id': 21123},
#     {'urlkey': 'computer-science', 'name': 'Computer Science', 'id': 21751},
#     {'urlkey': 'clojure', 'name': 'Clojure', 'id': 29661},
#     {'urlkey': 'erlang-programming',
#      'name': 'Erlang Programming',
#      'id': 46514},
#     {'urlkey': 'computer-programming',
#      'name': 'Computer programming',
#      'id': 48471},
#     {'urlkey': 'ios-development', 'name': 'iOS Development', 'id': 127567}],
#    'link': 'https://www.meetup.com/hack-and-tell/',
#    'rating': 4.82,
#    'description': '<p>If you\'ve ever visited <a href="http://news.ycombinator.com">Hacker News</a>, you\'ve almost certainly seen the "Show HN" or "Ask HN" posts. Well, it\'s time to get off the Internet and tell us about it face to face. We\'ll provide you with our honest feedback, you provide us with a great hack or idea.</p>\n<p>We\'ll give you 5 minutes to show off your tool, hack, library (did you just write a library to access the Meetup API in Go!?), whatever. We\'re language / software/ hardware agnostic, so it\'s all fair game.</p>\n<p>After you present, it\'s an open forum. The audience will ask questions and provide feedback. We want to enable as much participation as possible at these meetups, so you\'d better be able to take criticism and dish it out (all within reason of course).</p>\n<p>Our mailing list has a strict no recruiters and no promotion of commercial projects policy. If you think that your message to the list might not be appropriate, either run it by the organizers, or don\'t send it! Violators will be banned as soon as possible--no questions asked!</p>\n<ul> \n</ul>',
#    'lon': -74,
#    'group_photo': {'highres_link': 'https://secure.meetupstatic.com/photos/event/7/3/3/a/highres_440189498.jpeg',
#     'photo_id': 440189498,
#     'base_url': 'https://secure.meetupstatic.com',
#     'type': 'event',
#     'photo_link': 'https://secure.meetupstatic.com/photos/event/7/3/3/a/600_440189498.jpeg',
#     'thumb_link': 'https://secure.meetupstatic.com/photos/event/7/3/3/a/thumb_440189498.jpeg'},
#    'join_mode': 'open',
#    'organizer': {'member_id': 11712982,
#     'name': 'Danielle Sucher',
#     'photo': {'highres_link': 'https://secure.meetupstatic.com/photos/member/2/6/f/e/highres_100929982.jpeg',
#      'photo_id': 100929982,
#      'base_url': 'https://secure.meetupstatic.com',
#      'type': 'member',
#      'photo_link': 'https://secure.meetupstatic.com/photos/member/2/6/f/e/member_100929982.jpeg',
#      'thumb_link': 'https://secure.meetupstatic.com/photos/member/2/6/f/e/thumb_100929982.jpeg'}},
#    'members': 3949,
#    'name': 'Hack && Tell',
#    'id': 1673005,
#    'state': 'NY',
#    'urlname': 'hack-and-tell',
#    'category': {'name': 'tech', 'id': 34, 'shortname': 'tech'},
#    'lat': 40.720001220703125,
#    'who': 'Hackers'},
#   {'utc_offset': -14400000,
#    'country': 'US',
#    'visibility': 'public',
#    'city': 'New York',
#    'timezone': 'US/Eastern',
#    'created': 1308916327000,
#    'topics': [{'urlkey': 'php', 'name': 'PHP', 'id': 455},
#     {'urlkey': 'python', 'name': 'Python', 'id': 1064},
#     {'urlkey': 'blackbiz', 'name': 'Black Professionals', 'id': 2494},
#     {'urlkey': 'softwaredev', 'name': 'Software Development', 'id': 3833},
#     {'urlkey': 'consciousness', 'name': 'Consciousness', 'id': 4417},
#     {'urlkey': 'newtech', 'name': 'New Technology', 'id': 9696},
#     {'urlkey': 'internetpro', 'name': 'Internet Professionals', 'id': 10102},
#     {'urlkey': 'web', 'name': 'Web Technology', 'id': 10209},
#     {'urlkey': 'technology', 'name': 'Technology', 'id': 10579},
#     {'urlkey': 'information-technology',
#      'name': 'Information Technology',
#      'id': 15568},
#     {'urlkey': 'web-development', 'name': 'Web Development', 'id': 15582},
#     {'urlkey': 'computer-science', 'name': 'Computer Science', 'id': 21751},
#     {'urlkey': 'computer-programming',
#      'name': 'Computer programming',
#      'id': 48471},
#     {'urlkey': 'computer-geeks', 'name': 'Computer Geeks', 'id': 87762},
#     {'urlkey': 'it-professionals', 'name': 'IT Professionals', 'id': 164111}],
#    'link': 'https://www.meetup.com/hackmosaic/',
#    'rating': 4.53,
#    'description': '<p>Hack Mosaic is a meetup for Engineerings of Color get together and talk shop. Each meetup will be based around a specific topic with lightning talks / demos and networking.<br></p>',
#    'lon': -74,
#    'group_photo': {'highres_link': 'https://secure.meetupstatic.com/photos/event/e/1/5/9/highres_458157689.jpeg',
#     'photo_id': 458157689,
#     'base_url': 'https://secure.meetupstatic.com',
#     'type': 'event',
#     'photo_link': 'https://secure.meetupstatic.com/photos/event/e/1/5/9/600_458157689.jpeg',
#     'thumb_link': 'https://secure.meetupstatic.com/photos/event/e/1/5/9/thumb_458157689.jpeg'},
#    'join_mode': 'open',
#    'organizer': {'member_id': 13899291,
#     'name': 'Kyle Wanamaker',
#     'photo': {'highres_link': 'https://secure.meetupstatic.com/photos/member/7/e/7/6/highres_11912374.jpeg',
#      'photo_id': 11912374,
#      'base_url': 'https://secure.meetupstatic.com',
#      'type': 'member',
#      'photo_link': 'https://secure.meetupstatic.com/photos/member/7/e/7/6/member_11912374.jpeg',
#      'thumb_link': 'https://secure.meetupstatic.com/photos/member/7/e/7/6/thumb_11912374.jpeg'}},
#    'members': 1934,
#    'name': 'Hack Mosaic',
#    'id': 2072531,
#    'state': 'NY',
#    'urlname': 'hackmosaic',
#    'category': {'name': 'tech', 'id': 34, 'shortname': 'tech'},
#    'lat': 40.720001220703125,
#    'who': 'Hackers'},
#   {'utc_offset': -14400000,
#    'country': 'US',
#    'visibility': 'public',
#    'city': 'New York',
#    'timezone': 'US/Eastern',
#    'created': 1331908629000,
#    'topics': [{'urlkey': 'go', 'name': 'Go', 'id': 412},
#     {'urlkey': 'ruby', 'name': 'Ruby', 'id': 1040},
#     {'urlkey': 'python', 'name': 'Python', 'id': 1064},
#     {'urlkey': 'javascript', 'name': 'JavaScript', 'id': 7029},
#     {'urlkey': 'cloud-computing', 'name': 'Cloud Computing', 'id': 15167},
#     {'urlkey': 'high-scalability-computing',
#      'name': 'High Scalability Computing',
#      'id': 24410},
#     {'urlkey': 'nodejs', 'name': 'nodeJS', 'id': 101960},
#     {'urlkey': 'concurrent-programming',
#      'name': 'Concurrent Programming',
#      'id': 107751},
#     {'urlkey': 'go-programming-language',
#      'name': 'Go (Programming Language)',
#      'id': 336801},
#     {'urlkey': 'golang', 'name': 'Golang', 'id': 336811}],
#    'link': 'https://www.meetup.com/golanguagenewyork/',
#    'rating': 4.4,
#    'description': '<p>This group brings together the growing community of Go Language users.</p>',
#    'lon': -73.98999786376953,
#    'group_photo': {'highres_link': 'https://secure.meetupstatic.com/photos/event/7/d/3/1/highres_464912049.jpeg',
#     'photo_id': 464912049,
#     'base_url': 'https://secure.meetupstatic.com',
#     'type': 'event',
#     'photo_link': 'https://secure.meetupstatic.com/photos/event/7/d/3/1/600_464912049.jpeg',
#     'thumb_link': 'https://secure.meetupstatic.com/photos/event/7/d/3/1/thumb_464912049.jpeg'},
#    'join_mode': 'open',
#    'organizer': {'member_id': 9591484,
#     'name': 'Gray Herter',
#     'photo': {'highres_link': 'https://secure.meetupstatic.com/photos/member/3/8/3/9/highres_9794393.jpeg',
#      'photo_id': 9794393,
#      'base_url': 'https://secure.meetupstatic.com',
#      'type': 'member',
#      'photo_link': 'https://secure.meetupstatic.com/photos/member/3/8/3/9/member_9794393.jpeg',
#      'thumb_link': 'https://secure.meetupstatic.com/photos/member/3/8/3/9/thumb_9794393.jpeg'}},
#    'members': 1392,
#    'name': 'Go Language NYC',
#    'id': 3489922,
#    'state': 'NY',
#    'urlname': 'golanguagenewyork',
#    'category': {'name': 'tech', 'id': 34, 'shortname': 'tech'},
#    'lat': 40.75,
#    'who': 'Gophers'},
#   {'utc_offset': -14400000,
#    'country': 'US',
#    'visibility': 'public',
#    'city': 'New York',
#    'timezone': 'US/Eastern',
#    'created': 1345260230000,
#    'topics': [{'urlkey': 'webstandards', 'name': 'Web Standards', 'id': 417},
#     {'urlkey': 'opensource', 'name': 'Open Source', 'id': 563},
#     {'urlkey': 'webdesign', 'name': 'Web Design', 'id': 659},
#     {'urlkey': 'python', 'name': 'Python', 'id': 1064},
#     {'urlkey': 'softwaredev', 'name': 'Software Development', 'id': 3833},
#     {'urlkey': 'internetpro', 'name': 'Internet Professionals', 'id': 10102},
#     {'urlkey': 'web', 'name': 'Web Technology', 'id': 10209},
#     {'urlkey': 'web-development', 'name': 'Web Development', 'id': 15582},
#     {'urlkey': 'computer-programming',
#      'name': 'Computer programming',
#      'id': 48471},
#     {'urlkey': 'pyladies', 'name': 'PyLadies', 'id': 357041}],
#    'link': 'https://www.meetup.com/NYC-PyLadies/',
#    'rating': 4.76,
#    'description': '<p><span>A group for Python ladies of all levels of programming experience, in the NYC metro area.&nbsp;&nbsp;</span></p>\n<p><span>**Trans women welcome.**<br> </span></p>\n<p><a href="http://pyladies.com/">Pyladies</a> is an international mentorship group with a focus on helping more women become active participants and leaders in the Python open-source community. <strong>Our mission is to promote, educate and advance a diverse Python community through outreach, education, conferences, events and social gatherings</strong>.</p>\n<p>PyLadies also aims to provide a friendly support network for women and a bridge to the larger Python world.&nbsp;</p>\n<p><b>We ask that men bring a female guest if they will be attending an event.</b></p>\n<p>Code of Conduct: &nbsp;<a href="http://www.pyladies.com/CodeOfConduct/">http://www.pyladies.com/CodeOfConduct/</a></p>Mission: &nbsp;\n<a href="http://www.pyladies.com/">http://www.pyladies.com</a>\n<p>GitHub:&nbsp;&nbsp;<a href="https://github.com/NYCpyladies" class="linkified">https://github.com/NYCpyladies</a></p>',
#    'lon': -73.98999786376953,
#    'group_photo': {'highres_link': 'https://secure.meetupstatic.com/photos/event/6/6/5/a/highres_266426202.jpeg',
#     'photo_id': 266426202,
#     'base_url': 'https://secure.meetupstatic.com',
#     'type': 'event',
#     'photo_link': 'https://secure.meetupstatic.com/photos/event/6/6/5/a/600_266426202.jpeg',
#     'thumb_link': 'https://secure.meetupstatic.com/photos/event/6/6/5/a/thumb_266426202.jpeg'},
#    'join_mode': 'open',
#    'organizer': {'member_id': 76583532,
#     'name': 'NYC PyLadies',
#     'photo': {'highres_link': 'https://secure.meetupstatic.com/photos/member/6/6/0/highres_156421632.jpeg',
#      'photo_id': 156421632,
#      'base_url': 'https://secure.meetupstatic.com',
#      'type': 'member',
#      'photo_link': 'https://secure.meetupstatic.com/photos/member/6/6/0/member_156421632.jpeg',
#      'thumb_link': 'https://secure.meetupstatic.com/photos/member/6/6/0/thumb_156421632.jpeg'}},
#    'members': 2922,
#    'name': 'NYC PyLadies',
#    'id': 4576312,
#    'state': 'NY',
#    'urlname': 'NYC-PyLadies',
#    'category': {'name': 'tech', 'id': 34, 'shortname': 'tech'},
#    'lat': 40.75,
#    'who': 'Pythonistas'},
#   {'utc_offset': -14400000,
#    'country': 'US',
#    'visibility': 'public',
#    'city': 'New York',
#    'timezone': 'US/Eastern',
#    'created': 1347332426000,
#    'topics': [{'urlkey': 'webdesign', 'name': 'Web Design', 'id': 659},
#     {'urlkey': 'graphicdesign', 'name': 'Graphic Design', 'id': 781},
#     {'urlkey': 'python', 'name': 'Python', 'id': 1064},
#     {'urlkey': 'productdesign', 'name': 'Product Design', 'id': 2993},
#     {'urlkey': 'newtech', 'name': 'New Technology', 'id': 9696},
#     {'urlkey': 'ixd', 'name': 'Interaction Design', 'id': 10110},
#     {'urlkey': 'web-development', 'name': 'Web Development', 'id': 15582},
#     {'urlkey': 'mobile-technology', 'name': 'Mobile Technology', 'id': 16216},
#     {'urlkey': 'entrepreneurship', 'name': 'Entrepreneurship', 'id': 19882},
#     {'urlkey': 'ruby-on-rails', 'name': 'Ruby On Rails', 'id': 20837},
#     {'urlkey': 'mobile-development',
#      'name': 'Mobile Development',
#      'id': 21441},
#     {'urlkey': 'geeks-nerds', 'name': 'Geeks & Nerds', 'id': 32623},
#     {'urlkey': 'technology-startups',
#      'name': 'Technology Startups',
#      'id': 108403},
#     {'urlkey': 'ios-development', 'name': 'iOS Development', 'id': 127567},
#     {'urlkey': 'internet-startups',
#      'name': 'Internet Startups',
#      'id': 128595}],
#    'link': 'https://www.meetup.com/Designers-Geeks-NY/',
#    'rating': 4.78,
#    'description': '<p>Bringing designers + geeks together to talk shop, startups, and do some knowledge sharing. All types of designers + geeks welcome.</p>\n<p><b> <br></b></p>\n<p><b>Designers + Geeks Newsletter</b></p>\n<p>All Designers + Geeks events, news, and giveaways are announced through our newsletter. You can subscribe to it here:</p>\n<p><a href="https://www.designersandgeeks.com/">Join The&nbsp;Designers + Geeks Newsletter</a></p>\n<p>We hate spam, and will only use your contact info for Designers + Geeks news.</p>\n<p><b> <br></b></p>\n<p><b>Connect with us on Twitter &amp; Facebook:</b></p>\n<p><a href="http://twitter.com/DesignersGeeks">@DesignersGeeks</a></p>\n<p><a href="https://www.facebook.com/pages/Designers-Geeks/125590974193923">Facebook Page</a></p>',
#    'lon': -73.98999786376953,
#    'join_mode': 'open',
#    'organizer': {'member_id': 9732581,
#     'name': 'Joe Robinson',
#     'photo': {'highres_link': 'https://secure.meetupstatic.com/photos/member/9/9/e/5/highres_258099397.jpeg',
#      'photo_id': 258099397,
#      'base_url': 'https://secure.meetupstatic.com',
#      'type': 'member',
#      'photo_link': 'https://secure.meetupstatic.com/photos/member/9/9/e/5/member_258099397.jpeg',
#      'thumb_link': 'https://secure.meetupstatic.com/photos/member/9/9/e/5/thumb_258099397.jpeg'}},
#    'members': 10117,
#    'name': 'Designers + Geeks New York',
#    'id': 4873782,
#    'state': 'NY',
#    'urlname': 'Designers-Geeks-NY',
#    'category': {'name': 'tech', 'id': 34, 'shortname': 'tech'},
#    'lat': 40.7400016784668,
#    'who': 'Designers + Geeks'},
#   {'utc_offset': -14400000,
#    'country': 'US',
#    'visibility': 'public',
#    'city': 'New York',
#    'timezone': 'US/Eastern',
#    'created': 1349801507000,
#    'topics': [{'urlkey': 'java', 'name': 'Java', 'id': 189},
#     {'urlkey': 'unix', 'name': 'Unix', 'id': 405},
#     {'urlkey': 'opensource', 'name': 'Open Source', 'id': 563},
#     {'urlkey': 'ruby', 'name': 'Ruby', 'id': 1040},
#     {'urlkey': 'python', 'name': 'Python', 'id': 1064},
#     {'urlkey': 'css', 'name': 'CSS', 'id': 1973},
#     {'urlkey': 'softwaredev', 'name': 'Software Development', 'id': 3833},
#     {'urlkey': 'javascript', 'name': 'JavaScript', 'id': 7029},
#     {'urlkey': 'technology', 'name': 'Technology', 'id': 10579},
#     {'urlkey': 'web-development', 'name': 'Web Development', 'id': 15582},
#     {'urlkey': 'ruby-on-rails', 'name': 'Ruby On Rails', 'id': 20837},
#     {'urlkey': 'hacking', 'name': 'Hacking', 'id': 21123},
#     {'urlkey': 'computer-programming',
#      'name': 'Computer programming',
#      'id': 48471},
#     {'urlkey': 'html', 'name': 'HTML', 'id': 53518},
#     {'urlkey': 'social-coding', 'name': 'Social Coding', 'id': 90286}],
#    'link': 'https://www.meetup.com/hackerhours/',
#    'rating': 4.7,
#    'description': '<p><b>Free office hours for programming help - any programming language, all skill levels</b>. The format is super simple: you come with your laptop, sit and hang out and code, and flag down one of the organizers if you have a question. &nbsp;That\'s it! If we can\'t answer your question, we\'ll find you someone who can, or at least point you in the right direction.</p>\n<p>Note that this is a meetup for people learning to code. Experienced developers are more than welcome, though - we appreciate the help! For those hiring or simply interested in supporting free learning in NYC, we are open to sponsorships, so just <a href="http://nyc.hackerhours.org/suggestion/">reach out</a>! No recruiting without permission from the organizer(s). <b>Feel free to use the mailing list</b>:&nbsp;<a href="mailto:hackerhours-list@meetup.com">hackerhours-list@meetup.com</a>, but check out&nbsp;<a href="http://hackerhours.org/policies.html">our policies</a>. Also, <b>check out&nbsp;the homepage&nbsp;for Resources, Tutors, etc.</b></p>\n<p>*****************</p>\n<p><a href="http://hackerhours.org">hackerhours.org</a></p>\n<p>*****************</p>',
#    'lon': -73.98999786376953,
#    'group_photo': {'highres_link': 'https://secure.meetupstatic.com/photos/event/3/7/7/a/highres_199874202.jpeg',
#     'photo_id': 199874202,
#     'base_url': 'https://secure.meetupstatic.com',
#     'type': 'event',
#     'photo_link': 'https://secure.meetupstatic.com/photos/event/3/7/7/a/600_199874202.jpeg',
#     'thumb_link': 'https://secure.meetupstatic.com/photos/event/3/7/7/a/thumb_199874202.jpeg'},
#    'join_mode': 'open',
#    'organizer': {'member_id': 8818215,
#     'name': 'Aidan Feldman',
#     'photo': {'highres_link': 'https://secure.meetupstatic.com/photos/member/9/b/f/b/highres_258819931.jpeg',
#      'photo_id': 258819931,
#      'base_url': 'https://secure.meetupstatic.com',
#      'type': 'member',
#      'photo_link': 'https://secure.meetupstatic.com/photos/member/9/b/f/b/member_258819931.jpeg',
#      'thumb_link': 'https://secure.meetupstatic.com/photos/member/9/b/f/b/thumb_258819931.jpeg'}},
#    'members': 5895,
#    'name': 'Hacker Hours',
#    'id': 5314302,
#    'state': 'NY',
#    'urlname': 'hackerhours',
#    'category': {'name': 'tech', 'id': 34, 'shortname': 'tech'},
#    'lat': 40.7599983215332,
#    'who': 'Haxors'},
#   {'utc_offset': -14400000,
#    'country': 'US',
#    'visibility': 'public',
#    'city': 'New York',
#    'timezone': 'US/Eastern',
#    'created': 1355290984000,
#    'topics': [{'urlkey': 'ai', 'name': 'Artificial Intelligence', 'id': 456},
#     {'urlkey': 'robotics', 'name': 'Robotics', 'id': 682},
#     {'urlkey': 'python', 'name': 'Python', 'id': 1064},
#     {'urlkey': 'machine-learning', 'name': 'Machine Learning', 'id': 29971},
#     {'urlkey': 'neural-networks', 'name': 'Neural Networks', 'id': 39679},
#     {'urlkey': 'data-science', 'name': 'Data Science', 'id': 102811},
#     {'urlkey': 'applied-statistics',
#      'name': 'Applied Statistics',
#      'id': 115913},
#     {'urlkey': 'gpu-programming', 'name': 'GPU Programming', 'id': 148580}],
#    'link': 'https://www.meetup.com/NYC-Neural-Network-Aficionados-Discussion-Group/',
#    'rating': 0,
#    'description': "<p>This is a group for anyone interested in research concerning artificial neural networks, deep learning, and so on. The format varies between discussion groups, guest speakers, and tutorials. Proposed topics include: training deep belief networks with unsupervised pre-training/supervised finetuning, recurrent neural networks, different optimization methods, scalable architectures for large networks across clusters, practical GPU programming (with Python!), NNs for NLP, using NNs in robotics, visualizations to monitor NN learning, and other stuff specific to these areas of research. Recent developments in this area of research show a lot of promise, but very few people within the machine learning community have any practical experience with these methods. Since there's so few of us, we should get together and share notes!</p>",
#    'lon': -74,
#    'group_photo': {'highres_link': 'https://secure.meetupstatic.com/photos/event/3/9/0/a/highres_187394602.jpeg',
#     'photo_id': 187394602,
#     'base_url': 'https://secure.meetupstatic.com',
#     'type': 'event',
#     'photo_link': 'https://secure.meetupstatic.com/photos/event/3/9/0/a/600_187394602.jpeg',
#     'thumb_link': 'https://secure.meetupstatic.com/photos/event/3/9/0/a/thumb_187394602.jpeg'},
#    'join_mode': 'open',
#    'organizer': {'member_id': 12580139,
#     'name': 'Dave Sullivan',
#     'photo': {'highres_link': 'https://secure.meetupstatic.com/photos/member/3/0/9/0/highres_40332432.jpeg',
#      'photo_id': 40332432,
#      'base_url': 'https://secure.meetupstatic.com',
#      'type': 'member',
#      'photo_link': 'https://secure.meetupstatic.com/photos/member/3/0/9/0/member_40332432.jpeg',
#      'thumb_link': 'https://secure.meetupstatic.com/photos/member/3/0/9/0/thumb_40332432.jpeg'}},
#    'members': 455,
#    'name': 'NYC Neural Network Aficionados Discussion Group',
#    'id': 6210392,
#    'state': 'NY',
#    'urlname': 'NYC-Neural-Network-Aficionados-Discussion-Group',
#    'category': {'name': 'tech', 'id': 34, 'shortname': 'tech'},
#    'lat': 40.720001220703125,
#    'who': 'Neural Networkers'},
#   {'utc_offset': -14400000,
#    'country': 'US',
#    'visibility': 'public',
#    'city': 'New York',
#    'timezone': 'US/Eastern',
#    'created': 1355452080000,
#    'topics': [{'urlkey': 'python', 'name': 'Python', 'id': 1064},
#     {'urlkey': 'big-data', 'name': 'Big Data', 'id': 18062},
#     {'urlkey': 'machine-learning', 'name': 'Machine Learning', 'id': 29971},
#     {'urlkey': 'data-analytics', 'name': 'Data Analytics', 'id': 30928},
#     {'urlkey': 'data-visualization',
#      'name': 'Data Visualization',
#      'id': 37381},
#     {'urlkey': 'predictive-analytics',
#      'name': 'Predictive Analytics',
#      'id': 38458},
#     {'urlkey': 'data-mining', 'name': 'Data Mining', 'id': 55324},
#     {'urlkey': 'data-science', 'name': 'Data Science', 'id': 102811}],
#    'link': 'https://www.meetup.com/ny-python-data-science/',
#    'rating': 4.6,
#    'description': "<p>This group is open to all folks interested in the intersection of Python and Data Science,. Send us a note if you'd like to host or present at one of our meetups.</p>",
#    'lon': -73.98999786376953,
#    'join_mode': 'open',
#    'organizer': {'member_id': 210380781,
#     'name': 'Global Data Geeks',
#     'photo': {'highres_link': 'https://secure.meetupstatic.com/photos/member/5/5/a/2/highres_267741922.jpeg',
#      'photo_id': 267741922,
#      'base_url': 'https://secure.meetupstatic.com',
#      'type': 'member',
#      'photo_link': 'https://secure.meetupstatic.com/photos/member/5/5/a/2/member_267741922.jpeg',
#      'thumb_link': 'https://secure.meetupstatic.com/photos/member/5/5/a/2/thumb_267741922.jpeg'}},
#    'members': 1146,
#    'name': 'NY Python Data Science',
#    'id': 6233002,
#    'state': 'NY',
#    'urlname': 'ny-python-data-science',
#    'category': {'name': 'tech', 'id': 34, 'shortname': 'tech'},
#    'lat': 40.7400016784668,
#    'who': 'Pythonistas'},
#   {'utc_offset': -14400000,
#    'country': 'US',
#    'visibility': 'public',
#    'city': 'New York',
#    'timezone': 'US/Eastern',
#    'created': 1358618480000,
#    'topics': [{'urlkey': 'opensource', 'name': 'Open Source', 'id': 563},
#     {'urlkey': 'webdesign', 'name': 'Web Design', 'id': 659},
#     {'urlkey': 'ruby', 'name': 'Ruby', 'id': 1040},
#     {'urlkey': 'python', 'name': 'Python', 'id': 1064},
#     {'urlkey': 'softwaredev', 'name': 'Software Development', 'id': 3833},
#     {'urlkey': 'javascript', 'name': 'JavaScript', 'id': 7029},
#     {'urlkey': 'newtech', 'name': 'New Technology', 'id': 9696},
#     {'urlkey': 'internetpro', 'name': 'Internet Professionals', 'id': 10102},
#     {'urlkey': 'technology', 'name': 'Technology', 'id': 10579},
#     {'urlkey': 'web-development', 'name': 'Web Development', 'id': 15582},
#     {'urlkey': 'ruby-on-rails', 'name': 'Ruby On Rails', 'id': 20837},
#     {'urlkey': 'startup-businesses',
#      'name': 'Startup Businesses',
#      'id': 21681},
#     {'urlkey': 'computer-programming',
#      'name': 'Computer programming',
#      'id': 48471},
#     {'urlkey': 'html5', 'name': 'HTML5', 'id': 78565}],
#    'link': 'https://www.meetup.com/codecrewny/',
#    'rating': 4.64,
#    'description': '<p>Coders + <span>Designers</span> + Entrepreneurs&nbsp;= Code Crew!</p>\n<p><strong>Passionate about learning how to code, creating beautiful designs or building the prototype for your business idea and tired of doing it alone? Then this is the group for you!</strong></p>\n<p><span>Want to learn how to build your own personal website, launch an MVP for a startup idea or take the first steps to a new career as a software developer without breaking the bank? If so then this group is for you!&nbsp;This is the perfect group for people serious about learning how to code. We provide affordable introductory class, courses and workshops on a myriad of programming topics. These topics include, but are not limited to,&nbsp;HTML, CSS, Javascript, Node.js, Ruby, Ruby on Rails, Python, Django, PHP, Objective-C, Swift, UI/UX Design and more!</span></p>\n<p><span>If you are interested in learning through self-study using resources on the web like Code School, Codecademy, Treehouse, P2PU, Coursera, edX, Udacity, programming books, screencasts or whatever else is out there on the internet we have helpful suggested readings on our&nbsp;<a href="http://blog.codecrew.co/">blog</a>. If you\'re just starting out and want to get a head start then check out some cool resources&nbsp;<a href="http://codecrew.co/resources">here</a>. &nbsp;</span></p>\n<p>Rather learn in a structured format? Check out our classes and workshops, which are super affordable!</p>\n<ul> \n</ul>',
#    'lon': -74,
#    'group_photo': {'highres_link': 'https://secure.meetupstatic.com/photos/event/b/b/6/6/highres_447827974.jpeg',
#     'photo_id': 447827974,
#     'base_url': 'https://secure.meetupstatic.com',
#     'type': 'event',
#     'photo_link': 'https://secure.meetupstatic.com/photos/event/b/b/6/6/600_447827974.jpeg',
#     'thumb_link': 'https://secure.meetupstatic.com/photos/event/b/b/6/6/thumb_447827974.jpeg'},
#    'join_mode': 'open',
#    'organizer': {'member_id': 48157942,
#     'name': 'Jamal',
#     'photo': {'highres_link': 'https://secure.meetupstatic.com/photos/member/7/7/9/1/highres_273390609.jpeg',
#      'photo_id': 273390609,
#      'base_url': 'https://secure.meetupstatic.com',
#      'type': 'member',
#      'photo_link': 'https://secure.meetupstatic.com/photos/member/7/7/9/1/member_273390609.jpeg',
#      'thumb_link': 'https://secure.meetupstatic.com/photos/member/7/7/9/1/thumb_273390609.jpeg'}},
#    'members': 11517,
#    'name': 'Code Crew - Learn to Code!',
#    'id': 6737712,
#    'state': 'NY',
#    'urlname': 'codecrewny',
#    'category': {'name': 'tech', 'id': 34, 'shortname': 'tech'},
#    'lat': 40.7400016784668,
#    'who': 'Swabbies'},
#   {'utc_offset': -14400000,
#    'country': 'US',
#    'visibility': 'public',
#    'city': 'New York',
#    'timezone': 'US/Eastern',
#    'created': 1358789640000,
#    'topics': [{'urlkey': 'opensource', 'name': 'Open Source', 'id': 563},
#     {'urlkey': 'python', 'name': 'Python', 'id': 1064},
#     {'urlkey': 'machine-learning', 'name': 'Machine Learning', 'id': 29971},
#     {'urlkey': 'quantitative-finance',
#      'name': 'Quantitative Finance',
#      'id': 34637},
#     {'urlkey': 'predictive-analytics',
#      'name': 'Predictive Analytics',
#      'id': 38458},
#     {'urlkey': 'computer-programming',
#      'name': 'Computer programming',
#      'id': 48471},
#     {'urlkey': 'quantitative-analysis',
#      'name': 'Quantitative Analysis',
#      'id': 54631},
#     {'urlkey': 'matlab', 'name': 'Matlab', 'id': 73744},
#     {'urlkey': 'data', 'name': 'Data', 'id': 480642}],
#    'link': 'https://www.meetup.com/NY-Quantitative-Python-User-Group/',
#    'rating': 4.65,
#    'description': '<p>A group of professionals using the Python programming language in quantitative applications (algorithms, visualization, number crunching, statistics) in the New York metro area.</p>',
#    'lon': -73.97000122070312,
#    'join_mode': 'open',
#    'organizer': {'member_id': 151044842,
#     'name': 'Enthought',
#     'photo': {'highres_link': 'https://secure.meetupstatic.com/photos/member/a/e/e/e/highres_224084782.jpeg',
#      'photo_id': 224084782,
#      'base_url': 'https://secure.meetupstatic.com',
#      'type': 'member',
#      'photo_link': 'https://secure.meetupstatic.com/photos/member/a/e/e/e/member_224084782.jpeg',
#      'thumb_link': 'https://secure.meetupstatic.com/photos/member/a/e/e/e/thumb_224084782.jpeg'}},
#    'members': 730,
#    'name': 'NY Quantitative Python User Group',
#    'id': 6769252,
#    'state': 'NY',
#    'urlname': 'NY-Quantitative-Python-User-Group',
#    'category': {'name': 'tech', 'id': 34, 'shortname': 'tech'},
#    'lat': 40.7599983215332,
#    'who': 'python enthusiasts'},
#   {'utc_offset': -14400000,
#    'country': 'US',
#    'visibility': 'public',
#    'city': 'New York',
#    'timezone': 'US/Eastern',
#    'created': 1362145350000,
#    'topics': [{'urlkey': 'python', 'name': 'Python', 'id': 1064},
#     {'urlkey': 'javascript', 'name': 'JavaScript', 'id': 7029},
#     {'urlkey': 'django', 'name': 'Django', 'id': 10553},
#     {'urlkey': 'computer-programming',
#      'name': 'Computer programming',
#      'id': 48471},
#     {'urlkey': 'html5', 'name': 'HTML5', 'id': 78565}],
#    'link': 'https://www.meetup.com/Django-Coding-Club/',
#    'rating': 4.62,
#    'description': "<p>Are you coding a Django app? So are we! We want to get together and hack with other New Yorkers, share tips, host office hours, and basically try to make it as easy and socially rewarding as possible for us Django folks.</p>\n<p>This group is for hackers. Our meetups will be about writing code, so if you're not doing that, there are probably better meetups for you to join. This definitely isn't meant to be anyone's free recruiting pool. We do welcome students, people just getting started, developer evangelists and other folks who can help us code better.</p>",
#    'lon': -74,
# ...
#    'lon': -84.4000015258789,
#    'group_photo': {'highres_link': 'https://secure.meetupstatic.com/photos/event/e/2/d/d/highres_462358077.jpeg',
#     'photo_id': 462358077,
#     'base_url': 'https://secure.meetupstatic.com',
#     'type': 'event',
#     'photo_link': 'https://secure.meetupstatic.com/photos/event/e/2/d/d/600_462358077.jpeg',
#     'thumb_link': 'https://secure.meetupstatic.com/photos/event/e/2/d/d/thumb_462358077.jpeg'},
#    'join_mode': 'open',
#    'organizer': {'member_id': 214325931,
#     'name': 'Catherine',
#     'photo': {'highres_link': 'https://secure.meetupstatic.com/photos/member/8/6/f/5/highres_260734549.jpeg',
#      'photo_id': 260734549,
#      'base_url': 'https://secure.meetupstatic.com',
#      'type': 'member',
#      'photo_link': 'https://secure.meetupstatic.com/photos/member/8/6/f/5/member_260734549.jpeg',
#      'thumb_link': 'https://secure.meetupstatic.com/photos/member/8/6/f/5/thumb_260734549.jpeg'}},
#    'members': 2923,
#    'name': 'Learn to Code | Thinkful Atlanta',
#    'id': 20599024,
#    'state': 'GA',
#    'urlname': 'Atlanta-Tech-Talent-Pipeline',
#    'category': {'name': 'tech', 'id': 34, 'shortname': 'tech'},
#    'lat': 33.86000061035156,
#    'who': 'Members'},
#   {'utc_offset': -14400000,
#    'country': 'US',
#    'visibility': 'public',
#    'city': 'Atlanta',
#    'timezone': 'US/Eastern',
#    'created': 1490288101000,
#    'topics': [{'urlkey': 'ai', 'name': 'Artificial Intelligence', 'id': 456},
#     {'urlkey': 'python', 'name': 'Python', 'id': 1064},
#     {'urlkey': 'sas', 'name': 'SAS', 'id': 27497},
#     {'urlkey': 'machine-learning', 'name': 'Machine Learning', 'id': 29971},
#     {'urlkey': 'data-analytics', 'name': 'Data Analytics', 'id': 30928},
#     {'urlkey': 'data-visualization',
#      'name': 'Data Visualization',
#      'id': 37381},
#     {'urlkey': 'predictive-analytics',
#      'name': 'Predictive Analytics',
#      'id': 38458},
#     {'urlkey': 'data-mining', 'name': 'Data Mining', 'id': 55324},
#     {'urlkey': 'r-project-for-statistical-computing',
#      'name': 'R Project for Statistical Computing',
#      'id': 98380},
#     {'urlkey': 'data-science', 'name': 'Data Science', 'id': 102811},
#     {'urlkey': 'big-data-analytics',
#      'name': 'Big Data Analytics',
#      'id': 383411},
#     {'urlkey': 'clustering', 'name': 'Clustering', 'id': 584912},
#     {'urlkey': 'artificial-intelligence-programming',
#      'name': 'Artificial Intelligence Programming',
#      'id': 745722},
#     {'urlkey': 'artificial-intelligence-machine-learning-robotics',
#      'name': 'Artificial Intelligence Machine Learning Robotics',
#      'id': 1448582},
#     {'urlkey': 'deep-learning', 'name': 'Deep Learning', 'id': 1456952}],
#    'link': 'https://www.meetup.com/big-bang-Data-science-Solutions/',
#    'rating': 4.33,
#    'description': '<p>Welcome to Big Bang Data Science Solutions Inc</p>\n<p>Big Bang Data Science Solutions trains individuals and corporations on translating large, structured&nbsp;and unstructured, complex data into information to improve&nbsp;decision making. Our advanced curriculum includes a heavy emphasis on Data Science programming (R &amp; Python), Data Visualization Machine Learning, and Deep Learning from Zero to Hero. It also helps clients uncover actionable insights to drive competitive advantage and capture business value.&nbsp;</p>\n<p>We help individuals starting in data science-related fields or those seeking to improve their data science skills in data preprocessing, data mining, visualization, machine learning, and deep learning.&nbsp; We offer in-depth courses to fit your needs on your data scientist pathway, by interacting synchronously with instructors and utilizing industry tools and languages.</p>\n<p>&nbsp;<span>We help organizations integrate and operationalize data analytics solutions, enabling them to gain visibility into previously opaque or hard to measure processes; empowering our clients to make smarter business decisions.&nbsp;</span></p>\n<p>Our team of data science professors, data experts, consultants, and data scientists leverage proven analytics methodologies, tools, and best practices to define the right analytics training and solutions for you and your organization. We help prepare clients to solve complex business challenges with specific use cases to drive future growth.</p>\n<p><b>Our programs Include:</b></p>\n<p><i>End to End Data Science Program</i></p>\n<p><a href="http://www.bigbang-datascience.com/data-science-12-weeks-program-details/">http://www.bigbang-datascience.com/data-science-12-weeks-program-details/</a>&nbsp;</p>\n<p><i>Practical Machine Learning with Python Scikit-Learn&nbsp; Program&nbsp;</i></p>\n<p><a href="http://www.bigbang-datascience.com/practical-machine-learning-with-python-scikit-learn-details/">http://www.bigbang-datascience.com/practical-machine-learning-with-python-scikit-learn-details/</a>&nbsp;</p>\n<p><i>Practical Deep Learning with Python TensorFlow&nbsp; Program&nbsp;</i></p>\n<p><span><a href="http://www.bigbang-datascience.com/practical-deep-learning-with-tensorflow-details/" class="linkified">http://www.bigbang-datascience.com/practica...</a></span> <br></p>\n<p><i>SAP ARIBA (8 weeks)</i></p>\n<p><a href="http://www.bigbang-datascience.com/cloud/">http://www.bigbang-datascience.com/cloud/</a></p>\n<p><b>Program Highlights:&nbsp;</b></p>\n<p>•&nbsp; Hybrid classes (Virtual and physical)</p>\n<p>•&nbsp; Flexible schedule (Evenings and weekends)</p>\n<p>• 36 +&nbsp; LABS (12 Tableau Labs - 12 Python Labs -&nbsp; 12 R Labs and more )&nbsp;</p>\n<p>• 3 + Cohort Projects &amp; 1 Group Project&nbsp;</p>\n<p>• 12 +&nbsp; Mini projects (R &amp; Python)&nbsp;</p>\n<p>•&nbsp; Extensive Live Online Training</p>\n<p>•&nbsp; Instructor-Led Course</p>\n<p>•&nbsp; Training Video Recordings</p>\n<p>•&nbsp; Quality Training Materials</p>\n<p>•&nbsp; Two-Way Interactive Sessions</p>\n<p>•&nbsp; Job Oriented Training</p>\n<p>•&nbsp; Mock Exam/ Graded Assessments</p>\n<p>•&nbsp; Professional Certificate</p>\n<p>•&nbsp; Interview Prep Job Placement and Placement Guidance</p>\n<p>•&nbsp; Repeat any time at no cost</p>\n<p>• Extra help if needed 24/7&nbsp;</p>\n<p> <br></p>\n<p><span>Happy Data Science Journey!</span></p>\n<p>Mo Medwani</p>\n<p>Medwani@hotmail.com <br><a>6782099780</a> <br></p>',
#    'lon': -84.38999938964844,
#    'group_photo': {'highres_link': 'https://secure.meetupstatic.com/photos/event/9/1/2/c/highres_467737164.jpeg',
#     'photo_id': 467737164,
#     'base_url': 'https://secure.meetupstatic.com',
#     'type': 'event',
#     'photo_link': 'https://secure.meetupstatic.com/photos/event/9/1/2/c/600_467737164.jpeg',
#     'thumb_link': 'https://secure.meetupstatic.com/photos/event/9/1/2/c/thumb_467737164.jpeg'},
#    'join_mode': 'open',
#    'organizer': {'member_id': 222190623,
#     'name': 'Mo Medvani',
#     'photo': {'highres_link': 'https://secure.meetupstatic.com/photos/member/7/d/7/5/highres_265412117.jpeg',
#      'photo_id': 265412117,
#      'base_url': 'https://secure.meetupstatic.com',
#      'type': 'member',
#      'photo_link': 'https://secure.meetupstatic.com/photos/member/7/d/7/5/member_265412117.jpeg',
#      'thumb_link': 'https://secure.meetupstatic.com/photos/member/7/d/7/5/thumb_265412117.jpeg'}},
#    'members': 788,
#    'name': 'Big Bang Data Science - Georgia',
#    'id': 22983793,
#    'state': 'GA',
#    'urlname': 'big-bang-Data-science-Solutions',
#    'category': {'name': 'tech', 'id': 34, 'shortname': 'tech'},
#    'lat': 33.790000915527344,
#    'who': 'Members'},
#   {'utc_offset': -14400000,
#    'country': 'US',
#    'visibility': 'public',
#    'city': 'Atlanta',
#    'timezone': 'US/Eastern',
#    'created': 1499375717000,
#    'topics': [{'urlkey': 'opensource', 'name': 'Open Source', 'id': 563},
#     {'urlkey': 'python', 'name': 'Python', 'id': 1064},
#     {'urlkey': 'hadoop', 'name': 'Hadoop', 'id': 18060},
#     {'urlkey': 'big-data', 'name': 'Big Data', 'id': 18062},
#     {'urlkey': 'machine-learning', 'name': 'Machine Learning', 'id': 29971},
#     {'urlkey': 'data-analytics', 'name': 'Data Analytics', 'id': 30928},
#     {'urlkey': 'data-visualization',
#      'name': 'Data Visualization',
#      'id': 37381},
#     {'urlkey': 'predictive-analytics',
#      'name': 'Predictive Analytics',
#      'id': 38458},
#     {'urlkey': 'data-mining', 'name': 'Data Mining', 'id': 55324},
#     {'urlkey': 'data-science', 'name': 'Data Science', 'id': 102811},
#     {'urlkey': 'big-data-analytics',
#      'name': 'Big Data Analytics',
#      'id': 383411},
#     {'urlkey': 'data-science-using-python',
#      'name': 'Data Science using Python',
#      'id': 1481522},
#     {'urlkey': 'data-science-using-r',
#      'name': 'Data Science using R',
#      'id': 1512213},
#     {'urlkey': 'data-science-for-business',
#      'name': 'Data Science for Business',
#      'id': 1512214}],
#    'link': 'https://www.meetup.com/Atlanta-Data-Science-ODSC/',
#    'rating': 0,
#    'description': '<p>The focus of this meetup group is to present informative lectures, hands-on tutorials, and networking events to help grow the use of open source languages and tools within the data science and data-centric community. As such our specific goals are: 1. Host data science talks specific to our goals <br>2. Promote the use of open source languages and tools amongst data scientists and others. <br>3. Host educational workshops <br>4. Spread awareness of new open source languages and tools that can be used in data science <br>5. Contribute back to the open source community Who is this meetup for? <br>• Data engineers, analysts, scientists, and other practitioners <br>• R, Python and other software engineers who work with data <br>• Data visualization developers and designers <br>• Non-technical team leaders, executives and other decision makes from data centric startup and companies looking to utilize open source How can you get involved? • Attending events, network and precipitate! <br>• Give a talk or workshop that meets our goals <br>• Volunteer to help the group (social media, website, blogging) <br>• Provide us with a venue <br>• Sponsor food and beer.</p>',
#    'lon': -84.4000015258789,
#    'join_mode': 'open',
#    'organizer': {'member_id': 198384033,
#     'name': 'Vimal Patel',
#     'photo': {'highres_link': 'https://secure.meetupstatic.com/photos/member/2/9/8/5/highres_253690629.jpeg',
#      'photo_id': 253690629,
#      'base_url': 'https://secure.meetupstatic.com',
#      'type': 'member',
#      'photo_link': 'https://secure.meetupstatic.com/photos/member/2/9/8/5/member_253690629.jpeg',
#      'thumb_link': 'https://secure.meetupstatic.com/photos/member/2/9/8/5/thumb_253690629.jpeg'}},
#    'members': 96,
#    'name': 'Atlanta Data Science #ODSC',
#    'id': 24863086,
#    'state': 'GA',
#    'urlname': 'Atlanta-Data-Science-ODSC',
#    'category': {'name': 'tech', 'id': 34, 'shortname': 'tech'},
#    'lat': 33.86000061035156,
#    'who': 'Data Innovators'},
#   {'utc_offset': -14400000,
#    'country': 'US',
#    'visibility': 'public',
#    'city': 'Atlanta',
#    'timezone': 'US/Eastern',
#    'created': 1510943628000,
#    'topics': [{'urlkey': 'python', 'name': 'Python', 'id': 1064},
#     {'urlkey': 'big-data', 'name': 'Big Data', 'id': 18062},
#     {'urlkey': 'data-analytics', 'name': 'Data Analytics', 'id': 30928},
#     {'urlkey': 'data-visualization',
#      'name': 'Data Visualization',
#      'id': 37381},
#     {'urlkey': 'data-science', 'name': 'Data Science', 'id': 102811},
#     {'urlkey': 'big-data-analytics',
#      'name': 'Big Data Analytics',
#      'id': 383411}],
#    'link': 'https://www.meetup.com/Atlanta-Data-Science-Workshops/',
#    'rating': 5,
#    'description': '<p>Stuck learning Data Science on your own? You’re not alone! Join us for free, small-group workshops led by experienced engineers on weekdays at 7:00pm.</p>',
#    'lon': -84.37999725341797,
#    'group_photo': {'highres_link': 'https://secure.meetupstatic.com/photos/event/6/2/e/b/highres_466225323.jpeg',
#     'photo_id': 466225323,
#     'base_url': 'https://secure.meetupstatic.com',
#     'type': 'event',
#     'photo_link': 'https://secure.meetupstatic.com/photos/event/6/2/e/b/600_466225323.jpeg',
#     'thumb_link': 'https://secure.meetupstatic.com/photos/event/6/2/e/b/thumb_466225323.jpeg'},
#    'join_mode': 'open',
#    'organizer': {'member_id': 214325931,
#     'name': 'Catherine',
#     'photo': {'highres_link': 'https://secure.meetupstatic.com/photos/member/8/6/f/5/highres_260734549.jpeg',
#      'photo_id': 260734549,
#      'base_url': 'https://secure.meetupstatic.com',
#      'type': 'member',
#      'photo_link': 'https://secure.meetupstatic.com/photos/member/8/6/f/5/member_260734549.jpeg',
#      'thumb_link': 'https://secure.meetupstatic.com/photos/member/8/6/f/5/thumb_260734549.jpeg'}},
#    'members': 324,
#    'name': 'Atlanta Data Science Workshops',
#    'id': 26626721,
#    'state': 'GA',
#    'urlname': 'Atlanta-Data-Science-Workshops',
#    'category': {'name': 'tech', 'id': 34, 'shortname': 'tech'},
#    'lat': 33.77000045776367,
#    'who': 'Members'},
#   {'utc_offset': -14400000,
#    'country': 'US',
#    'visibility': 'public',
#    'city': 'Atlanta',
#    'timezone': 'US/Eastern',
#    'created': 1511195474000,
#    'topics': [{'urlkey': 'opensource', 'name': 'Open Source', 'id': 563},
#     {'urlkey': 'python', 'name': 'Python', 'id': 1064},
#     {'urlkey': 'computer-programming',
#      'name': 'Computer programming',
#      'id': 48471},
#     {'urlkey': 'data-science-using-python',
#      'name': 'Data Science using Python',
#      'id': 1481522}],
#    'link': 'https://www.meetup.com/Atlanta-Jupyter-User-Group/',
#    'rating': 4.92,
#    'description': '<p>The Atlanta Jupyter User Group is a local community of designers, developers and scientists using Jupyter notebooks.</p> \n<p>The user group meetings are afforable events that host 40-50 Jupyter users from the nearby Atlanta Metro Area. They will attract designers, developers, and scientists solving problems in applications that include:</p> \n<p>Education and training<br>Public health, medicine, and bioinformatics<br>Math, Science and, Engineering<br>Art, music, and making<br>Journalism, law, and policy<br>Visualization, UI, and UX</p>',
#    'lon': -84.4000015258789,
#    'join_mode': 'open',
#    'organizer': {'member_id': 112896572,
#     'name': 'Tony Fast',
#     'photo': {'highres_link': 'https://secure.meetupstatic.com/photos/member/4/f/6/4/highres_262940324.jpeg',
#      'photo_id': 262940324,
#      'base_url': 'https://secure.meetupstatic.com',
#      'type': 'member',
#      'photo_link': 'https://secure.meetupstatic.com/photos/member/4/f/6/4/member_262940324.jpeg',
#      'thumb_link': 'https://secure.meetupstatic.com/photos/member/4/f/6/4/thumb_262940324.jpeg'}},
#    'members': 141,
#    'name': 'Atlanta Jupyter User Group',
#    'id': 26653680,
#    'state': 'GA',
#    'urlname': 'Atlanta-Jupyter-User-Group',
#    'category': {'name': 'tech', 'id': 34, 'shortname': 'tech'},
#    'lat': 33.86000061035156,
#    'who': 'Members'}]}

# %% [markdown]
# Neat! We've started to organize our data and are on our way to extracting some tasty analyses! Let's look first at what the keys are of our newly created dictionary. How can we do this, again?

# %%
cities_keys = list(cities_dict.keys()) # assign the keys from the cities_dict to the variable cities_keys
cities_keys
# Out:
# ['New York',
#  'Bayside',
#  'Brooklyn',
#  'Yonkers',
#  'Forest Hills',
#  'San Francisco',
#  'Daly City',
#  'Berkeley',
#  'Oakland',
#  'San Mateo',
#  'Alameda',
#  'Denver',
#  'Englewood',
#  'Austin',
#  'Atlanta']

# %% [markdown]
# Looks like we've picked up a couple of extra cities! So far, we know that all of these cities have at least one group that focuses on Python. Let's dig and figure out how these cities compare.
#
# Write a method that returns a list of values which represent the number of groups in each city. Let's call it `tabulate_num_groups`. It should take a parameter of a dictionary, in this case our cities_dict, and return a list of the number of groups each city has.

# %% [markdown]
# > **Hint:** to make this more programmatic, you might think about using one of the functions we introduced that iterates over a collection, operates on each element and returns a list of the same length.

# %%
def count_groups(list):
    return len(list)

def tabulate_num_groups(dictionary):
    return map(count_groups, dictionary.values())
        
group_count_list = tabulate_num_groups(cities_dict) # assign your list of group counts to the variable group_count_list

# %% [markdown]
# Awesome, we've created a list containing the number of groups in each city. Let's start think about how we can visualize this data and start making some assumptions. Since we have lists of data, we should be in good shape to make a bar graph. Let's try it out!

# %%
import plotly
from plotly.offline import iplot, init_notebook_mode
from plotly import tools
import plotly.graph_objs as go
init_notebook_mode(connected=True)

trace = {'type': 'bar', 'x': list(cities_dict.keys()), 'y': list(group_count_list)}

plotly.offline.iplot({'data': [trace]})
# Out:
# <script>requirejs.config({paths: { 'plotly': ['https://cdn.plot.ly/plotly-latest.min']},});if(!window.Plotly) {{require(['plotly'],function(plotly) {window.Plotly=plotly;});}}</script>
# <div id="25f20729-a9fa-4353-a782-9f27dac242a2" style="height: 525px; width: 100%;" class="plotly-graph-div"></div><script type="text/javascript">require(["plotly"], function(Plotly) { window.PLOTLYENV=window.PLOTLYENV || {};window.PLOTLYENV.BASE_URL="https://plot.ly";Plotly.newPlot("25f20729-a9fa-4353-a782-9f27dac242a2", [{"type": "bar", "x": ["New York", "Bayside", "Brooklyn", "Yonkers", "Forest Hills", "San Francisco", "Daly City", "Berkeley", "Oakland", "San Mateo", "Alameda", "Denver", "Englewood", "Austin", "Atlanta"], "y": [62, 2, 7, 1, 1, 63, 1, 5, 5, 2, 1, 8, 1, 25, 14]}], {}, {"showLink": true, "linkText": "Export to plot.ly"})});</script>

# %% [markdown]
# Quite a close call, but it looks like New York and San Francisco take the top two spots -- who would have thought?

# %% [markdown]
# Okay, this is a start in the right direction, but can't anyone start a meetup group? What if there's only a few people in these groups? We have to start thinking about how we can be more critical about our data.
#
# Let's start with widdling down our list of groups so that it only includes groups that have over 300 members -- this should be substantial enough to ensure that the group is active and has a large network. It's a naive approach, but it should give us some better insights into which cities have the most active groups.
#
# We can write a function that will select only the groups that have `members` in excess of 300. Let's call it `get_active_groups`. It should take in our list of groups and return a pared down list with just the groups that have memberships above 300.

# %% [markdown]
# > **Hint:** This is good opportunity to again make our code more programmatic and use a function that takes in a list and iterates over each element selecting only the elements that pass our condition.

# %%
def big_groups(group):
    return group['members'] > 300

def get_active_groups(data):
    return list(filter(big_groups, data))

active_groups_list = get_active_groups(data)

None # assign the list of active groups to the variable active_groups_list

# %% [markdown]
# Alright, lets look at how many groups we were able to filter out of our initial list, `data`:

# %%
# print(len(data) - len(active_groups_list))

# %% [markdown]
# Alright, so, we removed 63 results from our list. Now we can re-chart our list and see what is looks like now. Before we do that, we need to recreate our dictionary from before. Good thing we have our function, `create_cities_dictionary` that creates the type of dictionary we need for us! Let's call this new dictionary `active_cities_dict`.

# %%
active_cities_dict = create_cities_dictionary(active_groups_list)
print(len(active_cities_dict['San Francisco']))
# Out:
# 44

# %% [markdown]
# Alright, we've got our updated dictionary and can now think about re-charting our data. But we also need to update our number of groups -- but we've got that part covered too with our previously written functions. Let's tabulate the group count again and then get our updated chart.

# %%
active_group_count_list = list(tabulate_num_groups(active_cities_dict))

# %%
import plotly
from plotly.offline import iplot, init_notebook_mode
from plotly import tools
import plotly.graph_objs as go
init_notebook_mode(connected=True)

trace = {'type': 'bar', 'x': list(active_cities_dict.keys()), 'y': active_group_count_list}

plotly.offline.iplot({'data': [trace]})
# Out:
# <script>requirejs.config({paths: { 'plotly': ['https://cdn.plot.ly/plotly-latest.min']},});if(!window.Plotly) {{require(['plotly'],function(plotly) {window.Plotly=plotly;});}}</script>
# <div id="ff762dda-6d3b-489d-87fe-b2f989348fe6" style="height: 525px; width: 100%;" class="plotly-graph-div"></div><script type="text/javascript">require(["plotly"], function(Plotly) { window.PLOTLYENV=window.PLOTLYENV || {};window.PLOTLYENV.BASE_URL="https://plot.ly";Plotly.newPlot("ff762dda-6d3b-489d-87fe-b2f989348fe6", [{"type": "bar", "x": ["New York", "Brooklyn", "San Francisco", "Daly City", "Berkeley", "Oakland", "Denver", "Englewood", "Austin", "Atlanta"], "y": [44, 3, 44, 1, 4, 4, 5, 1, 17, 12]}], {}, {"showLink": true, "linkText": "Export to plot.ly"})});</script>

# %% [markdown]
# It's a dead heat! New York, well Manhattan, and San Francisco are tied. So, we've pared down our list and our results are still pretty similar to before, but we have a better idea of which cities have the most active Python communities.
#
# Let's take our analysis a step further. We have decided data science is the life we want to live and we now want to find where we want to live and work once we've completed this course. Another naive, but useful approach would be to look at where these groups are located. Remember the maps we used earlier in this section? We're going to bring those back!
#
# Below, we have set up the map with a view of the US:

# %%
import folium
python_map = folium.Map([40.342140, -99.699511], zoom_start = 4)
python_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# Okay, very cool but boring. Let's start adding markers to our map.
# We can make markers by calling folium.Marker and passing in a list with the latitude and longitude of the thing we are trying to mark (e.g. `folium.Marker([latitude], [longitude])`). Let's write a function that takes in our active groups and adds a marker to our map. This function should be called `add_markers` and take in two parameters; a list of groups and the map to which you would like to add the marker.

# %%
def add_markers(group_list, selected_map):
    for group in group_list:
        folium.Marker([group['lat'], group['lon']]).add_to(selected_map)

add_markers(active_groups_list, python_map)

python_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# Nice! We ploted all the markers on the map. Now we can really visualize where all the python hubs are. From our chart, we can tell that the action is heavily concentrated in California and New York. So, we can gather that if we want to position ourselves to have a strong network of fellow data scienctists and Python lovers, we'll need to consider living in one of these locations. Let's make two maps -- one map for the Python groups in New York and then one for the Python groups in California.
# Let's go back to our original list of groups and select only the ones whose state is the state we want. We can again use a function that iterates over a collection and only selects the elements that pass our condition. We will call it `select_groups_from_state`. It should take in a parameter which is the desired state and it should return a list of groups that are located in that state.

# %% [markdown]
# > **Hint:** The `state` key points to the initials for that state (e.g. NY for New York & CA for California)

# %%
def filter_group_by_state(group, state):
    return group['state'] == state

def select_groups_from_state(state):
    return list(filter(lambda group: filter_group_by_state(group, state), data))

# %% [markdown]
# Okay, this is great. We now have a way to capture only the events from a specified state. Let's map them now, below we've supplied two maps that will center over NY and CA. Remember, we've set ourselves up so that we can easily add markers to a map with another function we've written...

# %%
CA_map = folium.Map([37.679238, -122.273028], zoom_start = 10)
NY_map = folium.Map([40.677887, -74.026795], zoom_start = 10)

# %%
add_markers(select_groups_from_state("CA"), CA_map)
CA_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
add_markers(select_groups_from_state("NY"), NY_map)
NY_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# Woah! Okay, so we've got another piece of data to add to our analysis. It looks like we can confidently pick either San Francisco or New York to live our new lives as data scientists with north easter San Francisco and Manhattan having the most Python groups.

# %% [markdown]
# ### Summary

# %% [markdown]
# In this lab, we used our skills to map, filter, chart, and plot data. We wrote functions to parse through hundreds of Meetup groups to find the ones that gave us the most relevant information. Finally we consolidated our data and created visualizations to help us make decisions based on this data.
